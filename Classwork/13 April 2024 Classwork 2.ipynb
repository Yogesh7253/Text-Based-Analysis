# %% [markdown]
# # CLASSWORK 2

# %% [markdown]
# # INSIGHTS ON UN GENERAL DEBATES BLUEPRINT DATA

# %%
#importing libraries

import pandas as pd
import seaborn as sns

# %%
# importimg data

df = pd.read_csv(r"C:\Users\Yogesh Bhardwaj\Downloads\un-general-debates-blueprint.csv")
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# 15       25  1970     DZA                          Algeria
# 16       25  1970     ECU                          Ecuador
# 17       25  1970     FRA                           France
# 18       25  1970     GBR                   United Kingdom
# 19       25  1970     GHA                            Ghana
#
#                   speaker    position  \
# 0                 Mr. NAS         NaN
# 1      Mr. DE PABLO PARDO         NaN
# 2             Mr. McMAHON         NaN
# 3      Mr. KIRCHSCHLAEGER         NaN
# 4              Mr. HARMEL         NaN
# 5          Mr. GURINOVICH         NaN
# 6      Mr. CAMACHO OMISTE         NaN
# 7      Mr. GIBSON BARBOZA         NaN
# 8               Mr. SHARP         NaN
# 9              Mr. AHIDJO  President
# 10            Mr. ICKONGA         NaN
# 11  Mr. VASQUEZ CARRIZOSA         NaN
# 12              Mr. FACIO         NaN
# 13            Mr. ALARCON         NaN
# 14        Mr FERNANDEZ G.
# 15              Mr. YAZID         NaN
# 16            Mr. Benites         NaN
# 17           Mr. SCHUMANN         NaN
# 18   Sir Alec DOUGLASHOME         NaN
# 19              Mr. OWUSU         NaN
#
#                                                  text
# 0   33: May I first convey to our President the co...
# 1   177.\t : It is a fortunate coincidence that pr...
# 2   100.\t  It is a pleasure for me to extend to y...
# 3   155.\t  May I begin by expressing to Ambassado...
# 4   176. No doubt each of us, before coming up to ...
# 5   \n71.\t. We are today mourning the untimely de...
# 6   135.\t  I wish to congratulate the President o...
# 7   1.\tMr. President, I should like, first of all...
# 8   \nThe General Assembly is fortunate indeed to ...
# 9   : A year ago I came here as the Acting Preside...
# 10  122.\t  I cannot begin my intervention without...
# 11  Mr. President, this visit to the United Nation...
# 12  62.\t  Mr. President, your election to the Pre...
# 13  1.\t  Mr. President, I should first like to co...
# 14  \n\n\n Mr. President, it was a source of great...
# 15  1.  The delegation of Algeria is very pleased ...
# 16  71.  It had been my hope that a loftier person...
# 17  84.\t  Within one month, when we celebrate the...
# 18  110.\t Mr. President, I should like first to s...
# 19  121.\t I should like to begin by congratulatin...

# %%
# Extracting 20% data to do further analysis

df = df.sample(frac=0.2)
df
# Out:
#       session  year country        country_name               speaker  \
# 5145       58  2003     PAK            Pakistan      Pervez Musharraf
# 6731       66  2011     ZWE            Zimbabwe         Robert Mugabe
# 4129       53  1998     CIV       Côte d'Ivoire            Amara Essy
# 6006       63  2008     CYP              Cyprus  Dimitris Christofias
# 6268       64  2009     MHL    Marshall Islands       Litokwa Tomeing
# ...       ...   ...     ...                 ...                   ...
# 3548       49  1994     TCD                Chad            Mr. Haggar
# 1301       35  1980     GRC              Greece            Mitsotakis
# 3830       51  1996     KOR  Korea, Republic of         Ro-Myung Gong
# 7410       70  2015     LBN             Lebanon      Mr. Tammam Salam
# 1250       35  1980     AUS           Australia               Peacock
#
#                           position  \
# 5145                     President
# 6731                     President
# 4129  Minister for Foreign Affairs
# 6006                     President
# 6268                     President
# ...                            ...
# 3548  Minister for Foreign Affairs
# 1301                           NaN
# 3830  Minister for Foreign Affairs
# 7410                Prime minister
# 1250                           NaN
#
#                                                    text
# 5145  ﻿It is with great pleasure\nthat I extend to y...
# 6731  I would like to take this \nopportunity to con...
# 4129  Allow me, Mr. President, to offer you my\nwarm...
# 6006  I wish first to extend \nsincere congratulatio...
# 6268  I bring the greetings and \nbest wishes of the...
# ...                                                 ...
# 3548  Allow me, Sir, to convey to you on behalf of t...
# 1301  ﻿Permit me first of all, Sir, to extend to you...
# 3830  ﻿On behalf of the\nGovernment and the people o...
# 7410  It is my pleasure, at the outset, to congratul...
# 1250  ﻿Mr. President, on behalf of the Australian de...
#
# [1501 rows x 7 columns]

# %%
# Column names

df.columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %%
# Data Types

df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %%
# Data Information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1501 entries, 5145 to 1250
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       1501 non-null   int64
#  1   year          1501 non-null   int64
#  2   country       1501 non-null   object
#  3   country_name  1501 non-null   object
#  4   speaker       1493 non-null   object
#  5   position      880 non-null    object
#  6   text          1501 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 93.8+ KB

# %%
# Describing the data 

df.describe()
# Out:
#            session         year
# count  1501.000000  1501.000000
# mean     49.498334  1994.498334
# std      12.783094    12.783094
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      50.000000  1995.000000
# 75%      60.000000  2005.000000
# max      70.000000  2015.000000

# %%
# Making a new length column to store the length of text

df['length'] = df['text'].str.len()
df.describe()
# Out:
#            session         year        length
# count  1501.000000  1501.000000   1501.000000
# mean     49.498334  1994.498334  17927.908728
# std      12.783094    12.783094   7791.141867
# min      25.000000  1970.000000   3377.000000
# 25%      39.000000  1984.000000  11913.000000
# 50%      50.000000  1995.000000  16508.000000
# 75%      60.000000  2005.000000  22505.000000
# max      70.000000  2015.000000  50319.000000

# %%
df.describe(include = 'O')
# Out:
#        country country_name                     speaker  \
# count     1501         1501                        1493
# unique     198          198                        1370
# top        BDI      Burundi  Pakalitha Bethuel Mosisili
# freq        15           15                           5
#
#                             position  \
# count                            880
# unique                            38
# top     Minister for Foreign Affairs
# freq                             345
#
#                                                      text
# count                                                1501
# unique                                               1501
# top     ﻿It is with great pleasure\nthat I extend to y...
# freq                                                    1

# %%
# Counting number of null values

df.isna().sum()
# Out:
# session           0
# year              0
# country           0
# country_name      0
# speaker           8
# position        621
# text              0
# length            0
# dtype: int64

# %%
# Filling the null values with 'unknown'

df['speaker'].fillna('unknown',inplace = True)
df['position'].fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %%
# Converting the text into uppercase

df['speaker'] = df['speaker'].str.upper()
df['position'] = df['position'].str.upper()
df['text'] = df['text'].str.upper()

# %%
# Speakers whose name contains 'BUSH'

df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name          speaker   position  \
# 3207       47  1992     USA  United States  MR. GEORGE BUSH  PRESIDENT
# 2876       45  1990     USA  United States      GEORGE BUSH    UNKNOWN
#
#                                                    text  length
# 3207  FORTY-SEVEN YEARS AGO I WAS A YOUNG MAN OF 21,...   21105
# 2876  ﻿\nIT IS REALLY A GREAT PRIVILEGE TO GREET YOU...   15843

# %%
# Unique Speakers

df['speaker'].unique()
# Out:
# array(['PERVEZ MUSHARRAF', 'ROBERT MUGABE', 'AMARA ESSY', ...,
#        'MITSOTAKIS', 'RO-MYUNG GONG', 'MR. TAMMAM SALAM'], dtype=object)

# %%
# Plotting the graph

df['length'].plot()
# Out:
# <Axes: >

# %%
# Plotting the box plot

df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %%
# Plotting the Histogram

df['length'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Plotting the box plot Country vs Length of speech

where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box')
g.fig.set_size_inches(10, 8)
# Out:
# C:\Users\Yogesh Bhardwaj\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Importing the regex library for regular expressions 

import regex as re

# %%
# Defining a function named tokenize which returns the aplhabets using regex

def tokenize(text):
    return re.findall('[\w-]*[a-z|A-Z][\w-]*',text)

# %%
# Calling our function tokenize

testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %%
# Importing the Natural Language Toolkit library

import nltk

# %%
# Downloading the stopwords package from nltk library

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Yogesh
# [nltk_data]     Bhardwaj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Storing the stopwords from stopwards package and printing them 

stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'these', 'few', "that'll", 'other', "it's", 'to', 've', 'before', 'during', 'who', "mustn't", 'which', "you'd", 'all', 'any', 'aren', 'over', 'so', 'will', 'our', 'it', 'are', 'herself', 'were', 'for', 'between', 'once', 'too', 'them', 'do', 'no', 'above', 'each', 'very', 'have', 'same', 'shouldn', 'an', 'in', 'when', 'don', 'll', 'he', 'isn', 'am', "isn't", 'about', "doesn't", "you'll", 'hers', 'of', "don't", 'doesn', 'does', "shan't", 'ourselves', "couldn't", 'should', 'hadn', 'mustn', 'because', 'further', 'now', 'under', 'ain', 'couldn', 'those', "wasn't", 'after', 'needn', "you've", 'can', 'again', 'as', 'on', 'm', 'they', 'whom', 'below', 'him', 'from', 'yourselves', 'doing', "mightn't", 'having', 'nor', 'such', 'wouldn', 'not', 'my', 'myself', 'this', 'ours', 'against', 'had', 'was', 'down', 'what', 'd', 'she', "she's", 'weren', 'been', "won't", 'i', 'into', 'own', 'yourself', 'being', 'wasn', 'its', "didn't", 'hasn', 'me', 'you', 'there', 'didn', 'while', 'itself', "hadn't", "wouldn't", "aren't", 'if', 'up', 'mightn', 'until', 'by', 'that', 'only', 'won', 'your', 'or', 't', 'why', 'y', "haven't", 'theirs', 'has', 'out', 'more', 'the', 'just', 'through', "needn't", 'yours', 'shan', 'a', 'then', 'o', "hasn't", 'off', "weren't", "shouldn't", 'did', 'than', 'with', "should've", 're', 'himself', "you're", 's', 'her', 'is', 'and', 'at', 'both', 'we', 'where', 'here', 'their', 'haven', 'ma', 'themselves', 'be', 'most', 'how', 'some', 'but', 'his'}

# %%
# Defining a function named remove_stop which returns other words except stopwords

def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %%
# Convertingb the text in lowercase and storing it in pipeline

pipeline = [str.lower, tokenize, remove_stop]

# %%
# Defining a function named prepare which inputs text and pipeline and returns tokens

def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %%
# Making a new column tokens which stores the tokens

df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %%
# Making a new column num_tokens which stores the length of tokens

df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       session  year country        country_name           speaker  \
# 3548       49  1994     TCD                Chad        MR. HAGGAR
# 1301       35  1980     GRC              Greece        MITSOTAKIS
# 3830       51  1996     KOR  Korea, Republic of     RO-MYUNG GONG
# 7410       70  2015     LBN             Lebanon  MR. TAMMAM SALAM
# 1250       35  1980     AUS           Australia           PEACOCK
#
#                           position  \
# 3548  MINISTER FOR FOREIGN AFFAIRS
# 1301                       UNKNOWN
# 3830  MINISTER FOR FOREIGN AFFAIRS
# 7410                PRIME MINISTER
# 1250                       UNKNOWN
#
#                                                    text  length  \
# 3548  ALLOW ME, SIR, TO CONVEY TO YOU ON BEHALF OF T...   14118
# 1301  ﻿PERMIT ME FIRST OF ALL, SIR, TO EXTEND TO YOU...   19650
# 3830  ﻿ON BEHALF OF THE\nGOVERNMENT AND THE PEOPLE O...   20335
# 7410  IT IS MY PLEASURE, AT THE OUTSET, TO CONGRATUL...   10412
# 1250  ﻿MR. PRESIDENT, ON BEHALF OF THE AUSTRALIAN DE...   30075
#
#                                                  tokens  num_tokens
# 3548  [allow, sir, convey, behalf, people, governmen...        1163
# 1301  [permit, first, sir, extend, warmest, congratu...        1528
# 3830  [behalf, government, people, republic, korea, ...        1764
# 7410  [pleasure, outset, congratulate, president, pr...         885
# 1250  [mr, president, behalf, australian, delegation...        2430

# %%
# Importing Counter package from collections library

from collections import Counter

# %%
# Testing our package

tokens = tokenize("She likes my cats and my cats like my sofa.")
testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %%
# Adding more text to same token and then testing it.

more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %%
# Counting each token

counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('nations', 24923), ('international', 23762), ('united', 23696), ('world', 18129), ('countries', 17236)]

# %%
# we put the word frequency in it’s own dataframe for analysis

freq_df = pd.DataFrame.from_dict(counter,orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#                 freq
# token
# nations        24923
# international  23762
# united         23696
# world          18129
# countries      17236
# peace          14625
# development    12737
# states         11621
# security       11607
# people         11572

# %%
# Describing the frequency 

freq_df.describe()
# Out:
#                freq
# count  35585.000000
# mean      62.283715
# std      425.422181
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%       15.000000
# max    24923.000000

# %%
# Bar Chart Token vs Frequency

ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
# Importing the libraries wordcloud and matplotlib

from wordcloud import WordCloud
from matplotlib import pyplot as plt

# %%
text = df.query("year==2015" and "country=='USA'")['text'].values[0]

# %%
# Word Cloud

plt.figure(figsize=(14, 7))
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wc = WordCloud(background_color='white', width = 300, height=300,max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict())
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
